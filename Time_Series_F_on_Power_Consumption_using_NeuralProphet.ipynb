# %%
#Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Tetuan City power consumption.csv')

# %%
df.head()
# Out:
#         DateTime  Temperature  Humidity  Wind Speed  general diffuse flows  \
# 0  1/1/2017 0:00        6.559      73.8       0.083                  0.051
# 1  1/1/2017 0:10        6.414      74.5       0.083                  0.070
# 2  1/1/2017 0:20        6.313      74.5       0.080                  0.062
# 3  1/1/2017 0:30        6.121      75.0       0.083                  0.091
# 4  1/1/2017 0:40        5.921      75.7       0.081                  0.048
#
#    diffuse flows  Zone 1 Power Consumption  Zone 2  Power Consumption  \
# 0          0.119               34055.69620                16128.87538
# 1          0.085               29814.68354                19375.07599
# 2          0.100               29128.10127                19006.68693
# 3          0.096               28228.86076                18361.09422
# 4          0.085               27335.69620                17872.34043
#
#    Zone 3  Power Consumption
# 0                20240.96386
# 1                20131.08434
# 2                19668.43373
# 3                18899.27711
# 4                18442.40964

# %%
df.columns
# Out:
# Index(['DateTime', 'Temperature', 'Humidity', 'Wind Speed',
#        'general diffuse flows', 'diffuse flows', 'Zone 1 Power Consumption',
#        'Zone 2  Power Consumption', 'Zone 3  Power Consumption'],
#       dtype='object')

# %%
from datetime import datetime

# %%
  df["DateTime"] = pd.to_datetime(df["DateTime"],errors='coerce')

# %%
df["Month"]=df["DateTime"].dt.month

# %%
df["Hour"]=df["DateTime"].dt.hour

# %%
df["Minute"]=df["DateTime"].dt.minute

# %%
df["Week"]=df["DateTime"].dt.week
# Out:
# C:\Users\SHAH12~2\AppData\Local\Temp/ipykernel_8340/4206472863.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df["Week"]=df["DateTime"].dt.week

# %%
df["Year"]=df["DateTime"].dt.year

# %%
 df['dayofweek'] = df["DateTime"].dt.dayofweek

# %%
 df['dayofYear'] = df["DateTime"].dt.dayofyear

# %%
#transforming DateTime column into index
#df = df.set_index('DateTime')

# %%
df.head()
# Out:
#              DateTime  Temperature  Humidity  Wind Speed  \
# 0 2017-01-01 00:00:00        6.559      73.8       0.083
# 1 2017-01-01 00:10:00        6.414      74.5       0.083
# 2 2017-01-01 00:20:00        6.313      74.5       0.080
# 3 2017-01-01 00:30:00        6.121      75.0       0.083
# 4 2017-01-01 00:40:00        5.921      75.7       0.081
#
#    general diffuse flows  diffuse flows  Zone 1 Power Consumption  \
# 0                  0.051          0.119               34055.69620
# 1                  0.070          0.085               29814.68354
# 2                  0.062          0.100               29128.10127
# 3                  0.091          0.096               28228.86076
# 4                  0.048          0.085               27335.69620
#
#    Zone 2  Power Consumption  Zone 3  Power Consumption  Month  Hour  Minute  \
# 0                16128.87538                20240.96386      1     0       0
# 1                19375.07599                20131.08434      1     0      10
# 2                19006.68693                19668.43373      1     0      20
# 3                18361.09422                18899.27711      1     0      30
# 4                17872.34043                18442.40964      1     0      40
#
#    Week  Year  dayofweek  dayofYear
# 0    52  2017          6          1
# 1    52  2017          6          1
# 2    52  2017          6          1
# 3    52  2017          6          1
# 4    52  2017          6          1

# %%
df.tail()
# Out:
#                  DateTime  Temperature  Humidity  Wind Speed  \
# 52411 2017-12-30 23:10:00        7.010      72.4       0.080
# 52412 2017-12-30 23:20:00        6.947      72.6       0.082
# 52413 2017-12-30 23:30:00        6.900      72.8       0.086
# 52414 2017-12-30 23:40:00        6.758      73.0       0.080
# 52415 2017-12-30 23:50:00        6.580      74.1       0.081
#
#        general diffuse flows  diffuse flows  Zone 1 Power Consumption  \
# 52411                  0.040          0.096               31160.45627
# 52412                  0.051          0.093               30430.41825
# 52413                  0.084          0.074               29590.87452
# 52414                  0.066          0.089               28958.17490
# 52415                  0.062          0.111               28349.80989
#
#        Zone 2  Power Consumption  Zone 3  Power Consumption  Month  Hour  \
# 52411                26857.31820                14780.31212     12    23
# 52412                26124.57809                14428.81152     12    23
# 52413                25277.69254                13806.48259     12    23
# 52414                24692.23688                13512.60504     12    23
# 52415                24055.23167                13345.49820     12    23
#
#        Minute  Week  Year  dayofweek  dayofYear
# 52411      10    52  2017          5        364
# 52412      20    52  2017          5        364
# 52413      30    52  2017          5        364
# 52414      40    52  2017          5        364
# 52415      50    52  2017          5        364

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52416 entries, 0 to 52415
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   DateTime                   52416 non-null  datetime64[ns]
#  1   Temperature                52416 non-null  float64
#  2   Humidity                   52416 non-null  float64
#  3   Wind Speed                 52416 non-null  float64
#  4   general diffuse flows      52416 non-null  float64
#  5   diffuse flows              52416 non-null  float64
#  6   Zone 1 Power Consumption   52416 non-null  float64
#  7   Zone 2  Power Consumption  52416 non-null  float64
#  8   Zone 3  Power Consumption  52416 non-null  float64
#  9   Month                      52416 non-null  int64
#  10  Hour                       52416 non-null  int64
#  11  Minute                     52416 non-null  int64
#  12  Week                       52416 non-null  int64
#  13  Year                       52416 non-null  int64
#  14  dayofweek                  52416 non-null  int64
#  15  dayofYear                  52416 non-null  int64
# dtypes: datetime64[ns](1), float64(8), int64(7)
# memory usage: 6.4 MB

# %%
#Calculating 30-day, 45-day and 90-day Simple Moving Average (lagged features)

df['SMA15'] = df['Zone 1 Power Consumption'].rolling(15).mean()
df['SMA30'] = df['Zone 2  Power Consumption'].rolling(30).mean()
df['SMA45'] = df['Zone 3  Power Consumption'].rolling(45).mean()

df.head(5)
# Out:
#              DateTime  Temperature  Humidity  Wind Speed  \
# 0 2017-01-01 00:00:00        6.559      73.8       0.083
# 1 2017-01-01 00:10:00        6.414      74.5       0.083
# 2 2017-01-01 00:20:00        6.313      74.5       0.080
# 3 2017-01-01 00:30:00        6.121      75.0       0.083
# 4 2017-01-01 00:40:00        5.921      75.7       0.081
#
#    general diffuse flows  diffuse flows  Zone 1 Power Consumption  \
# 0                  0.051          0.119               34055.69620
# 1                  0.070          0.085               29814.68354
# 2                  0.062          0.100               29128.10127
# 3                  0.091          0.096               28228.86076
# 4                  0.048          0.085               27335.69620
#
#    Zone 2  Power Consumption  Zone 3  Power Consumption  Month  Hour  Minute  \
# 0                16128.87538                20240.96386      1     0       0
# 1                19375.07599                20131.08434      1     0      10
# 2                19006.68693                19668.43373      1     0      20
# 3                18361.09422                18899.27711      1     0      30
# 4                17872.34043                18442.40964      1     0      40
#
#    Week  Year  dayofweek  dayofYear  SMA15  SMA30  SMA45
# 0    52  2017          6          1    NaN    NaN    NaN
# 1    52  2017          6          1    NaN    NaN    NaN
# 2    52  2017          6          1    NaN    NaN    NaN
# 3    52  2017          6          1    NaN    NaN    NaN
# 4    52  2017          6          1    NaN    NaN    NaN

# %%
df.tail(5)
# Out:
#                  DateTime  Temperature  Humidity  Wind Speed  \
# 52411 2017-12-30 23:10:00        7.010      72.4       0.080
# 52412 2017-12-30 23:20:00        6.947      72.6       0.082
# 52413 2017-12-30 23:30:00        6.900      72.8       0.086
# 52414 2017-12-30 23:40:00        6.758      73.0       0.080
# 52415 2017-12-30 23:50:00        6.580      74.1       0.081
#
#        general diffuse flows  diffuse flows  Zone 1 Power Consumption  \
# 52411                  0.040          0.096               31160.45627
# 52412                  0.051          0.093               30430.41825
# 52413                  0.084          0.074               29590.87452
# 52414                  0.066          0.089               28958.17490
# 52415                  0.062          0.111               28349.80989
#
#        Zone 2  Power Consumption  Zone 3  Power Consumption  Month  Hour  \
# 52411                26857.31820                14780.31212     12    23
# 52412                26124.57809                14428.81152     12    23
# 52413                25277.69254                13806.48259     12    23
# 52414                24692.23688                13512.60504     12    23
# 52415                24055.23167                13345.49820     12    23
#
#        Minute  Week  Year  dayofweek  dayofYear         SMA15         SMA30  \
# 52411      10    52  2017          5        364  34403.447401  30908.499540
# 52412      20    52  2017          5        364  33990.570342  30687.327401
# 52413      30    52  2017          5        364  33540.380227  30438.662166
# 52414      40    52  2017          5        364  33082.078579  30176.250383
# 52415      50    52  2017          5        364  32597.820025  29893.341516
#
#               SMA45
# 52411  15368.195278
# 52412  15457.831132
# 52413  15534.661864
# 52414  15607.394958
# 52415  15670.396158

# %%
fig, ax = plt.subplots(figsize=(20, 10))

zone1 = sns.boxplot(data=df, x='Hour', y='Zone 1 Power Consumption', palette = 'Oranges', showfliers=False)
zone2 = sns.boxplot(data=df, x='Hour', y='Zone 2  Power Consumption', palette = 'Reds', showfliers=False)
zone3 = sns.boxplot(data=df, x='Hour', y='Zone 3  Power Consumption', palette = 'Blues', showfliers=False)

plt.suptitle('KW by Hour', fontsize=15)
plt.xlabel('hour', fontsize=12)
plt.ylabel('Power Consumption in KW', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

#Generating plot
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20, 10))

zone1 = sns.boxplot(data=df, x='Hour', y='Zone 1 Power Consumption', palette = 'Oranges', showfliers=False)
plt.suptitle('KW by Hour', fontsize=15)
plt.xlabel('hour', fontsize=12)
plt.ylabel('Power Consumption in KW', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

#Generating plot
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20, 10))

zone1 = sns.boxplot(data=df, x='Month', y='Zone 1 Power Consumption', palette = 'Reds', showfliers=False)
plt.suptitle('KW by Month', fontsize=15)
plt.xlabel('Month', fontsize=12)
plt.ylabel('Power Consumption in KW', fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

#Generating plot
plt.show()

# %%
df.rename(columns={'DateTime':'ds','Zone 1 Power Consumption':'y'},inplace='True')

# %%
df.columns
# Out:
# Index(['ds', 'Temperature', 'Humidity', 'Wind Speed', 'general diffuse flows',
#        'diffuse flows', 'y', 'Zone 2  Power Consumption',
#        'Zone 3  Power Consumption', 'Month', 'Hour', 'Minute', 'Week', 'Year',
#        'dayofweek', 'dayofYear', 'SMA15', 'SMA30', 'SMA45'],
#       dtype='object')

# %%
df.plot(x='ds',y='y',figsize=(28,16))
# Out:
# <AxesSubplot:xlabel='ds'>

# %%
#transforming DateTime column into index
df = df.set_index('ds')

# %%
len(df)
# Out:
# 52416

# %%
len(df)*0.75
# Out:
# 39312.0

# %%
train1= df.iloc[:39312]
test1= df.iloc[39312:]

# %%
train1
# Out:
#                      Temperature  Humidity  Wind Speed  general diffuse flows  \
# ds
# 2017-01-01 00:00:00        6.559      73.8       0.083                  0.051
# 2017-01-01 00:10:00        6.414      74.5       0.083                  0.070
# 2017-01-01 00:20:00        6.313      74.5       0.080                  0.062
# 2017-01-01 00:30:00        6.121      75.0       0.083                  0.091
# 2017-01-01 00:40:00        5.921      75.7       0.081                  0.048
# ...                          ...       ...         ...                    ...
# 2017-09-30 23:10:00       18.420      86.9       4.918                  0.084
# 2017-09-30 23:20:00       18.400      87.1       4.920                  0.062
# 2017-09-30 23:30:00       18.440      87.5       4.917                  0.055
# 2017-09-30 23:40:00       18.360      87.7       4.919                  0.062
# 2017-09-30 23:50:00       18.350      87.7       4.918                  0.077
#
#                      diffuse flows            y  Zone 2  Power Consumption  \
# ds
# 2017-01-01 00:00:00          0.119  34055.69620                16128.87538
# 2017-01-01 00:10:00          0.085  29814.68354                19375.07599
# 2017-01-01 00:20:00          0.100  29128.10127                19006.68693
# 2017-01-01 00:30:00          0.096  28228.86076                18361.09422
# 2017-01-01 00:40:00          0.085  27335.69620                17872.34043
# ...                            ...          ...                        ...
# 2017-09-30 23:10:00          0.085  35426.54867                20204.15800
# 2017-09-30 23:20:00          0.119  34738.40708                19785.03119
# 2017-09-30 23:30:00          0.152  34196.81416                19246.15385
# 2017-09-30 23:40:00          0.144  33438.58407                18789.60499
# 2017-09-30 23:50:00          0.115  32852.38938                18336.79834
#
#                      Zone 3  Power Consumption  Month  Hour  Minute  Week  \
# ds
# 2017-01-01 00:00:00                20240.96386      1     0       0    52
# 2017-01-01 00:10:00                20131.08434      1     0      10    52
# 2017-01-01 00:20:00                19668.43373      1     0      20    52
# 2017-01-01 00:30:00                18899.27711      1     0      30    52
# 2017-01-01 00:40:00                18442.40964      1     0      40    52
# ...                                        ...    ...   ...     ...   ...
# 2017-09-30 23:10:00                16256.26149      9    23      10    39
# 2017-09-30 23:20:00                15973.85087      9    23      20    39
# 2017-09-30 23:30:00                15620.83759      9    23      30    39
# 2017-09-30 23:40:00                15173.68744      9    23      40    39
# 2017-09-30 23:50:00                15120.73544      9    23      50    39
#
# 2017-01-01 00:20:00          6      1  2017  26037.063291           NaN
# 2017-01-01 00:30:00          6      1  2017  26037.063291           NaN
# 2017-01-01 00:40:00          6      1  2017  26037.063291           NaN
# ...                        ...    ...   ...           ...           ...
# 2017-10-01 23:10:00          6     10  2017  39907.851203  23729.626556
# 2017-10-01 23:20:00          6     10  2017  39184.385120  23562.572614
# 2017-10-01 23:30:00          6     10  2017  38414.284463  23362.531120
# 2017-10-01 23:40:00          6     10  2017  37617.715536  23140.954356
# 2017-10-01 23:50:00          6     10  2017  36794.678337  22914.024896
#
#                             SMA45            y
# ds
# 2017-01-01 00:00:00           NaN  34055.69620
# 2017-01-01 00:10:00           NaN  29814.68354
# 2017-01-01 00:20:00           NaN  29128.10127
# 2017-01-01 00:30:00           NaN  28228.86076
# 2017-01-01 00:40:00           NaN  27335.69620
# ...                           ...          ...
# 2017-10-01 23:10:00  16859.428571  34225.99562
# 2017-10-01 23:20:00  16904.429584  33450.85339
# 2017-10-01 23:30:00  16939.963526  32543.36980
# 2017-10-01 23:40:00  16976.145896  31799.73742
# 2017-10-01 23:50:00  17010.123606  31138.03063
#
# [39456 rows x 12 columns]

# %%
#reset index to default
#train.reset_index(inplace = True)

# %%
train = train['y']

# %%
train
# Out:
# ds
# 2017-01-01 00:00:00    34055.69620
# 2017-01-01 00:10:00    29814.68354
# 2017-01-01 00:20:00    29128.10127
# 2017-01-01 00:30:00    28228.86076
# 2017-01-01 00:40:00    27335.69620
#                           ...
# 2017-10-01 23:10:00    34225.99562
# 2017-10-01 23:20:00    33450.85339
# 2017-10-01 23:30:00    32543.36980
# 2017-10-01 23:40:00    31799.73742
# 2017-10-01 23:50:00    31138.03063
# Name: y, Length: 39456, dtype: float64

# %%
test = df.loc['10-01-2017':,['Humidity', 'Temperature', 'Wind Speed','dayofYear', 'Hour', 'dayofweek','Month', 'Year','SMA15', 'SMA30', 'SMA45','y']]

# %%
test=test['y']

# %%
test
# Out:
# ds
# 2017-10-01 00:00:00    31755.62363
# 2017-10-01 00:10:00    31175.84245
# 2017-10-01 00:20:00    30154.92341
# 2017-10-01 00:30:00    29764.20131
# 2017-10-01 00:40:00    29600.35011
#                           ...
# 2017-12-30 23:10:00    31160.45627
# 2017-12-30 23:20:00    30430.41825
# 2017-12-30 23:30:00    29590.87452
# 2017-12-30 23:40:00    28958.17490
# 2017-12-30 23:50:00    28349.80989
# Name: y, Length: 13104, dtype: float64

# %%
test.shape
# Out:
# (13104,)

# %%
train.shape
# Out:
# (39456,)

# %%
train_df = pd.DataFrame(train, columns = ['y'])

# %%
train_df.reset_index(inplace = True)

# %%
train_df
# Out:
#                        ds            y
# 0     2017-01-01 00:00:00  34055.69620
# 1     2017-01-01 00:10:00  29814.68354
# 2     2017-01-01 00:20:00  29128.10127
# 3     2017-01-01 00:30:00  28228.86076
# 4     2017-01-01 00:40:00  27335.69620
# ...                   ...          ...
# 39451 2017-10-01 23:10:00  34225.99562
# 39452 2017-10-01 23:20:00  33450.85339
# 39453 2017-10-01 23:30:00  32543.36980
# 39454 2017-10-01 23:40:00  31799.73742
# 39455 2017-10-01 23:50:00  31138.03063
#
# [39456 rows x 2 columns]

# %%
test_df = pd.DataFrame(test, columns = ['y'])

# %%
test_df.reset_index(inplace = True)

# %%
from neuralprophet import NeuralProphet

# %%
model = NeuralProphet(
    growth="linear",  # Determine trend types: 'linear', 'discontinuous', 'off'
    changepoints=None, # list of dates that may include change points (None -> automatic )
    n_changepoints=5,
    changepoints_range=0.8,
    trend_reg=0,
    trend_reg_threshold=False,
    yearly_seasonality="auto",
    weekly_seasonality="auto",
    daily_seasonality="auto",
    seasonality_mode="additive",
    seasonality_reg=0,
    n_forecasts=1,
    n_lags=0,
    num_hidden_layers=0,
    d_hidden=None,     # Dimension of hidden layers of AR-Net
    #ar_sparsity=None,  # Sparcity in the AR coefficients
    learning_rate=None,
    epochs=40,
    loss_func="Huber",
    normalize="auto",  # Type of normalization ('minmax', 'standardize', 'soft', 'off')
    impute_missing=True,
    #log_level=None, # Determines the logging level of the logger object
)

# %%
# %%time
metrics=model.fit(train_df,  
                 freq='MS', 
                    epochs=15)
# Out:
# WARNING - (NP.forecaster.fit) - When Global modeling with local normalization, metrics are displayed in normalized scale.
# INFO - (NP.df_utils._infer_frequency) - Major frequency 10T corresponds to 99.997% of the data.
# WARNING - (NP.df_utils._infer_frequency) - Defined frequency MS is different than major frequency 10T
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling yearly seasonality. Run NeuralProphet with yearly_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 64
# Finding best initial lr:   0%|          | 0/264 [00:00<?, ?it/s]
# Training: 0it [00:00, ?it/s]
# Wall time: 37.1 s

# %%
forecast=model.predict(test_df)
# Out:
# INFO - (NP.df_utils._infer_frequency) - Major frequency 10T corresponds to 99.992% of the data.
# WARNING - (NP.df_utils._infer_frequency) - Defined frequency MS is different than major frequency 10T
# INFO - (NP.df_utils._infer_frequency) - Major frequency 10T corresponds to 99.992% of the data.
# WARNING - (NP.df_utils._infer_frequency) - Defined frequency MS is different than major frequency 10T
# Predicting: 617it [00:00, ?it/s]
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column

# %%
fig1=model.plot(forecast)
# Out:
# WARNING - (NP.plotting.log_warning_deprecation_plotly) - DeprecationWarning: default plotting_backend will be changed to plotly in a future version. Switch to plotly by calling `m.set_plotting_backend('plotly')`.

# %%
fig2= model.plot_components(forecast)
plt.show()
# Out:
# WARNING - (NP.plotting.log_warning_deprecation_plotly) - DeprecationWarning: default plotting_backend will be changed to plotly in a future version. Switch to plotly by calling `m.set_plotting_backend('plotly')`.

# %%
forecast.head()
# Out:
#                    ds            y         yhat1         trend  season_weekly  \
# 0 2017-10-01 00:00:00  31755.62363  33414.769531  33992.230469   -1029.709473
# 1 2017-10-01 00:10:00  31175.84245  32723.925781  33992.062500   -1042.764038
# 2 2017-10-01 00:20:00  30154.92341  32058.300781  33991.894531   -1055.732178
# 3 2017-10-01 00:30:00  29764.20131  31422.996094  33991.726562   -1068.610229
# 4 2017-10-01 00:40:00  29600.35011  30823.078125  33991.558594   -1081.395142
#
#    season_daily
# 0    452.251709
# 1   -225.370728
# 2   -877.860046
# 3  -1500.119507
# 4  -2087.083252

# %%
final_df=pd.concat((forecast['yhat1'],test_df),axis=1)

# %%
final_df
# Out:
#               yhat1                  ds            y
# 0      33414.769531 2017-10-01 00:00:00  31755.62363
# 1      32723.925781 2017-10-01 00:10:00  31175.84245
# 2      32058.300781 2017-10-01 00:20:00  30154.92341
# 3      31422.996094 2017-10-01 00:30:00  29764.20131
# 4      30823.078125 2017-10-01 00:40:00  29600.35011
# ...             ...                 ...          ...
# 13099  34888.363281 2017-12-30 23:10:00  31160.45627
# 13100  34137.503906 2017-12-30 23:20:00  30430.41825
# 13101  33391.132812 2017-12-30 23:30:00  29590.87452
# 13102  32652.632812 2017-12-30 23:40:00  28958.17490
# 13103  31925.730469 2017-12-30 23:50:00  28349.80989
#
# [13104 rows x 3 columns]

# %%
plt.figure(figsize=(8,6))
plt.plot(final_df['ds'],final_df['y'],color='red',label='actual')
plt.plot(final_df['ds'],final_df['yhat1'],color='blue',label='forecast')
plt.legend()

# %%
forecast.columns
# Out:
# Index(['ds', 'y', 'yhat1', 'trend', 'season_weekly', 'season_daily'], dtype='object')

# %%
forecast
# Out:
#                        ds            y         yhat1         trend  \
# 0     2017-10-01 00:00:00  31755.62363  33414.769531  33992.230469
# 1     2017-10-01 00:10:00  31175.84245  32723.925781  33992.062500
# 2     2017-10-01 00:20:00  30154.92341  32058.300781  33991.894531
# 3     2017-10-01 00:30:00  29764.20131  31422.996094  33991.726562
# 4     2017-10-01 00:40:00  29600.35011  30823.078125  33991.558594
# ...                   ...          ...           ...           ...
# 13099 2017-12-30 23:10:00  31160.45627  34888.363281  31792.875000
# 13100 2017-12-30 23:20:00  30430.41825  34137.503906  31792.707031
# 13101 2017-12-30 23:30:00  29590.87452  33391.132812  31792.539062
# 13102 2017-12-30 23:40:00  28958.17490  32652.632812  31792.371094
# 13103 2017-12-30 23:50:00  28349.80989  31925.730469  31792.203125
#
#        season_weekly  season_daily
# 0       -1029.709473    452.251709
# 1       -1042.764038   -225.370728
# 2       -1055.732178   -877.860046
# 3       -1068.610229  -1500.119507
# 4       -1081.395142  -2087.083252
# ...              ...           ...
# 13099    -963.262024   4058.750977
# 13100    -976.696655   3321.492920
# 13101    -990.062134   2588.655029
# 13102   -1003.355103   1863.617188
# 13103   -1016.572021   1150.102051
#
# [13104 rows x 6 columns]

# %%
from statsmodels.tools.eval_measures import rmse

print ("RMSE: ", rmse(forecast['yhat1'],test_df['y']))
# Out:
# RMSE:  4022.108919676025

# %%
from sklearn.metrics import  mean_absolute_error

# %%
performance_MAE= mean_absolute_error(test_df['y'],forecast['yhat1'])
print(f'The MAE for the model is {performance_MAE}')
# Out:
# The MAE for the model is 3431.1376149714306

# %%
from sklearn.metrics import  r2_score

# %%
print (" r2_score: ",  r2_score(final_df['yhat1'],final_df['y']))
# Out:
#  r2_score:  0.600780109237274
